# %% [markdown]
# ### EDA

# %%
import pandas as pd

c = pd.read_csv('creditcard.csv')
c.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
c.shape
# Out:
# (284807, 31)

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
c.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
c['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
c.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
l = c[c['Class'] == 0]
f = c[c['Class'] == 1]

# %%
l.shape
# Out:
# (284315, 31)

# %%
f.shape
# Out:
# (492, 31)

# %%
l = l.sample(n = 492)
l.shape
# Out:
# (492, 31)

# %%
c = pd.concat([l,f], axis = 0)

# %%
c
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 202421  134320.0  1.763921 -1.537281 -0.563759 -0.644146 -1.343658 -0.520736
# 136059   81524.0 -1.204934  1.433359  1.316611 -0.306951 -0.088300 -0.270904
# 272606  165178.0 -0.617354  0.924031  1.415573  2.470043  1.510450  1.246942
# 168608  119305.0 -0.056774  1.059775 -0.121382  0.888117  1.316176 -0.382919
# 91568    63530.0 -1.074203  0.313706 -0.963371 -3.045080  2.101995  2.765093
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
c['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %% [markdown]
# ### Model

# %%
X = c.drop('Class', axis = True)
y = c['Class']

# %%
from sklearn.model_selection import train_test_split

a, d, s, f = train_test_split(X, y, test_size = 0.2, stratify = y, random_state = 9)

# %%
print(a.shape)
print(s.shape)
print(d.shape)
print(f.shape)
# Out:
# (787, 30)
# (787,)
# (197, 30)
# (197,)

# %%
from sklearn.linear_model import LogisticRegression

m = LogisticRegression()
m.fit(a,s)
g = m.predict(d)

# %%
from sklearn.metrics import accuracy_score

print('accuracy_score : ',accuracy_score(f, g))
# Out:
# accuracy_score :  0.9086294416243654

# %% [markdown]
# ### Prediction

# %%
z = (153633,2.03636960638989,-1.01056956896185,-0.542651643565587,-0.196882396420127,-0.982191940801555,-0.253915473128984,-0.862318670214514,-0.0471251663355806,0.0903572075616324,0.828629416910144,-1.72758907368801,-0.297628120309947,0.197781590111525,-0.200553611447188,0.451249899570234,-0.855718434143812,-0.521529022671065,1.26608958350069,-0.684468383402989,-0.496059118211694,-0.581891774103568,-1.22806570325075,0.359881425651015,-0.726414159766267,-0.624842228444307,0.0157232334016389,0.000117618615916165,-0.031152591376675,64.97)

import numpy as np
z = np.array(z)
z = z.reshape(1,-1)
m.predict(z)
# Out:
# C:\Users\sriha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
